# %%
import pandas as pd

# %%
df=pd.DataFrame({"EmployeeID": [101, 102, 103, 104, 105], "Name": ['Alice', 'Bob', 'Charlie', 'David', 'Eva'], 'Department': ['HR', 'IT', 'Finance', 'IT', 'HR'], 'Salary': [50000, 60000, 55000, 65000, 58000]
})

# %%
df
# Out:
#    EmployeeID     Name Department  Salary
# 0         101    Alice         HR   50000
# 1         102      Bob         IT   60000
# 2         103  Charlie    Finance   55000
# 3         104    David         IT   65000
# 4         105      Eva         HR   58000

# %%
df[["Name","Salary"]]
# Out:
#       Name  Salary
# 0    Alice   50000
# 1      Bob   60000
# 2  Charlie   55000
# 3    David   65000
# 4      Eva   58000

# %%
df[df['Department'] == 'IT']['Salary'].mean()
# Out:
# 62500.0

# %%
df["Bonus"]=df["Salary"]*0.1

# %%
df["EmployeeID"].rename("ID")
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# Name: ID, dtype: int64

# %%
df.drop(df[["Department"]],axis=1)
# Out:
#    EmployeeID     Name  Salary   Bonus
# 0         101    Alice   50000  5000.0
# 1         102      Bob   60000  6000.0
# 2         103  Charlie   55000  5500.0
# 3         104    David   65000  6500.0
# 4         105      Eva   58000  5800.0

# %%
sales_data=pd.DataFrame({"Month": ['Jan', 'Feb', 'Mar', 'Apr', 'May'], "Product_A": [150, 200, 250, 300, 350], "Product_B": [300, 250, 200, 150, 100]
})

# %%
sales_data["Total_sales"]=sales_data.iloc[:,1]+sales_data.iloc[:,2]

# %%
sales_data
# Out:
#   Month  Product_A  Product_B  Total_sales
# 0   Jan        150        300          450
# 1   Feb        200        250          450
# 2   Mar        250        200          450
# 3   Apr        300        150          450
# 4   May        350        100          450

# %%
sales_data["Product_A"]=sales_data["Product_A"]/sales_data["Product_A"].max()

# %%
sales_data
# Out:
#   Month  Product_A  Product_B  Total_sales
# 0   Jan   0.428571        300          450
# 1   Feb   0.571429        250          450
# 2   Mar   0.714286        200          450
# 3   Apr   0.857143        150          450
# 4   May   1.000000        100          450

# %%
sales_data[sales_data["Total_sales"]>400]
# Out:
#   Month  Product_A  Product_B  Total_sales
# 0   Jan   0.428571        300          450
# 1   Feb   0.571429        250          450
# 2   Mar   0.714286        200          450
# 3   Apr   0.857143        150          450
# 4   May   1.000000        100          450

# %%
customer_data=pd.DataFrame({"CustomerID": [1, 2, 3, 4, 5], "Name": ['John', 'Jane', None, 'Alice', 'Bob'], "Purchase": [200, 300, 150, None, 500]
})

# %%
customer_data
# Out:
#    CustomerID   Name  Purchase
# 0           1   John     200.0
# 1           2   Jane     300.0
# 2           3   None     150.0
# 3           4  Alice       NaN
# 4           5    Bob     500.0

# %%
customer_data[customer_data["Purchase"]>customer_data["Purchase"].median()]
# Out:
#    CustomerID  Name  Purchase
# 1           2  Jane     300.0
# 4           5   Bob     500.0

# %%
temperature=pd.Series([23, 21, 20, 25, 27, 30, 28, 22, 24, 26])

# %%
temperature.mean()
# Out:
# 24.6

# %%
temperature.median()
# Out:
# 24.5

# %%
temperature.var()
# Out:
# 10.266666666666667

# %%
temperature1=pd.Series(temperature>temperature.mean())

# %%
temperature1
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9     True
# dtype: bool

# %%
temperature=temperature+273.15

# %%
temperature
# Out:
# 0    569.3
# 1    567.3
# 2    566.3
# 3    571.3
# 4    573.3
# 5    576.3
# 6    574.3
# 7    568.3
# 8    570.3
# 9    572.3
# dtype: float64

# %%
rolling_mean=temperature.rolling(window=3).mean()

# %%
rolling_mean
# Out:
# 0           NaN
# 1           NaN
# 2    567.633333
# 3    568.300000
# 4    570.300000
# 5    573.633333
# 6    574.633333
# 7    572.966667
# 8    570.966667
# 9    570.300000
# dtype: float64

# %%
mean=temperature.mean()

# %%
std=temperature.std()

# %%
lb=mean-std
ub=mean+std

# %%
filter=[x for x in temperature if x<lb or x>ub]

# %%
orders=pd.DataFrame({"OrderID": [1, 2, 3, 4, 5], "CustomerID": [101, 102, 103, 104, 101], "Product": ['A', 'B', 'A', 'C', 'B'], "Quantity": [2, 1, 4, 2, 3]
})

# %%
customers=pd.DataFrame({"CustomerID": [101, 102, 103, 104], "Name": ['Alice', 'Bob', 'Charlie', 'David'], "Location": ['New York', 'Los Angeles', 'Chicago', 'Houston']
})

# %%
merged=pd.merge(orders,customers,on="CustomerID")

# %%
merged
# Out:
#    OrderID  CustomerID Product  Quantity     Name     Location
# 0        1         101       A         2    Alice     New York
# 1        5         101       B         3    Alice     New York
# 2        2         102       B         1      Bob  Los Angeles
# 3        3         103       A         4  Charlie      Chicago
# 4        4         104       C         2    David      Houston

# %%
quantity=merged.groupby('Location')['Quantity'].sum()

# %%
quantity
# Out:
# Location
# Chicago        4
# Houston        2
# Los Angeles    1
# New York       5
# Name: Quantity, dtype: int64

# %%
merged["CustomerID"].mode()
# Out:
# 0    101
# Name: CustomerID, dtype: int64

# %%
total_quantity_products=merged.groupby("Product")["Quantity"].sum()

# %%
total_quantity_products
# Out:
# Product
# A    6
# B    4
# C    2
# Name: Quantity, dtype: int64

# %%
filter=merged[merged["Product"].isin(['A','B'])]

# %%
filter
# Out:
#    OrderID  CustomerID Product  Quantity     Name     Location
# 0        1         101       A         2    Alice     New York
# 1        5         101       B         3    Alice     New York
# 2        2         102       B         1      Bob  Los Angeles
# 3        3         103       A         4  Charlie      Chicago
