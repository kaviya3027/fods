# %%
import pandas as pd

# %%
df=pd.read_excel('payroll_dataset.xlsx')

# %%
df1 = pd.read_excel('payroll_dataset.xlsx', sheet_name='Employees')
df2 = pd.read_excel('payroll_dataset.xlsx', sheet_name='Departments')

# %%
merge = pd.merge(df1, df2, on='DepartmentID')

# %%
merge
# Out:
#     EmployeeID          Name DepartmentID  Salary    HireDate  Location  \
# 0            1    Employee 1         D001    6000  2020-01-31  New York
# 1            5    Employee 5         D001    6400  2020-05-31  New York
# 2            9    Employee 9         D001    6800  2020-09-30  New York
# 3           13   Employee 13         D001    7200  2021-01-31  New York
# 4           17   Employee 17         D001    7600  2021-05-31  New York
# ..         ...           ...          ...     ...         ...       ...
# 95          84   Employee 84         D004   14300  2026-12-31   Houston
# 96          88   Employee 88         D004   14700  2027-04-30   Houston
# 97          92   Employee 92         D004   15100  2027-08-31   Houston
# 98          96   Employee 96         D004   15500  2027-12-31   Houston
# 99         100  Employee 100         D004   15900  2028-04-30   Houston
#
#    DepartmentName
# 0              IT
# 1              IT
# 2              IT
# 3              IT
# ...

# %%
merge.iloc[[0,1,2,3,4]]
# Out:
#    EmployeeID         Name DepartmentID  Salary    HireDate  Location  \
# 0           1   Employee 1         D001    6000  2020-01-31  New York
# 1           5   Employee 5         D001    6400  2020-05-31  New York
# 2           9   Employee 9         D001    6800  2020-09-30  New York
# 3          13  Employee 13         D001    7200  2021-01-31  New York
# 4          17  Employee 17         D001    7600  2021-05-31  New York
#
#   DepartmentName
# 0             IT
# 1             IT
# 2             IT
# 3             IT
# 4             IT

# %%
clean=merge.drop_duplicates()

# %%
clean
# Out:
#     EmployeeID          Name DepartmentID  Salary    HireDate  Location  \
# 0            1    Employee 1         D001    6000  2020-01-31  New York
# 1            5    Employee 5         D001    6400  2020-05-31  New York
# 2            9    Employee 9         D001    6800  2020-09-30  New York
# 3           13   Employee 13         D001    7200  2021-01-31  New York
# 4           17   Employee 17         D001    7600  2021-05-31  New York
# ..         ...           ...          ...     ...         ...       ...
# 95          84   Employee 84         D004   14300  2026-12-31   Houston
# 96          88   Employee 88         D004   14700  2027-04-30   Houston
# 97          92   Employee 92         D004   15100  2027-08-31   Houston
# 98          96   Employee 96         D004   15500  2027-12-31   Houston
# 99         100  Employee 100         D004   15900  2028-04-30   Houston
#
#    DepartmentName
# 0              IT
# 1              IT
# 2              IT
# 3              IT
# ...

# %%
merge.head(5)
# Out:
#    EmployeeID         Name DepartmentID  Salary    HireDate  Location  \
# 0           1   Employee 1         D001    6000  2020-01-31  New York
# 1           5   Employee 5         D001    6400  2020-05-31  New York
# 2           9   Employee 9         D001    6800  2020-09-30  New York
# 3          13  Employee 13         D001    7200  2021-01-31  New York
# 4          17  Employee 17         D001    7600  2021-05-31  New York
#
#   DepartmentName
# 0             IT
# 1             IT
# 2             IT
# 3             IT
# 4             IT

# %%
Q1=df1['Salary'].quantile(0.25)

# %%
Q3=df1['Salary'].quantile(0.75)

# %%
IQR=Q3-Q1

# %%
lb=Q1-0.5*IQR

# %%
ub=Q3+1.5*IQR

# %%
outlier=((df1[['Salary']]<lb) | (df1[['Salary']]>ub))

# %%
clean_ed=df1[~outlier]

# %%
clean_ed
# Out:
#     EmployeeID Name DepartmentID  Salary HireDate Location
# 0          NaN  NaN          NaN    6000      NaN      NaN
# 1          NaN  NaN          NaN    6100      NaN      NaN
# 2          NaN  NaN          NaN    6200      NaN      NaN
# 3          NaN  NaN          NaN    6300      NaN      NaN
# 4          NaN  NaN          NaN    6400      NaN      NaN
# ..         ...  ...          ...     ...      ...      ...
# 95         NaN  NaN          NaN   15500      NaN      NaN
# 96         NaN  NaN          NaN   15600      NaN      NaN
# 97         NaN  NaN          NaN   15700      NaN      NaN
# 98         NaN  NaN          NaN   15800      NaN      NaN
# 99         NaN  NaN          NaN   15900      NaN      NaN
#
# [100 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
df1['Salary']=scaler.fit_transform(df1[['Salary']])

# %%
df1
# Out:
#     EmployeeID          Name DepartmentID    Salary    HireDate     Location
# 0            1    Employee 1         D001  0.000000  2020-01-31     New York
# 1            2    Employee 2         D002  0.010101  2020-02-29  Los Angeles
# 2            3    Employee 3         D003  0.020202  2020-03-31      Chicago
# 3            4    Employee 4         D004  0.030303  2020-04-30      Houston
# 4            5    Employee 5         D001  0.040404  2020-05-31     New York
# ..         ...           ...          ...       ...         ...          ...
# 95          96   Employee 96         D004  0.959596  2027-12-31      Houston
# 96          97   Employee 97         D001  0.969697  2028-01-31     New York
# 97          98   Employee 98         D002  0.979798  2028-02-29  Los Angeles
# 98          99   Employee 99         D003  0.989899  2028-03-31      Chicago
# 99         100  Employee 100         D004  1.000000  2028-04-30      Houston
#
# [100 rows x 6 columns]

# %%
encode=pd.get_dummies(df1,columns=['Location'])

# %%
encode
# Out:
#     EmployeeID          Name DepartmentID    Salary    HireDate  \
# 0            1    Employee 1         D001  0.000000  2020-01-31
# 1            2    Employee 2         D002  0.010101  2020-02-29
# 2            3    Employee 3         D003  0.020202  2020-03-31
# 3            4    Employee 4         D004  0.030303  2020-04-30
# 4            5    Employee 5         D001  0.040404  2020-05-31
# ..         ...           ...          ...       ...         ...
# 95          96   Employee 96         D004  0.959596  2027-12-31
# 96          97   Employee 97         D001  0.969697  2028-01-31
# 97          98   Employee 98         D002  0.979798  2028-02-29
# 98          99   Employee 99         D003  0.989899  2028-03-31
# 99         100  Employee 100         D004  1.000000  2028-04-30
#
#     Location_Chicago  Location_Houston  Location_Los Angeles  \
# 0              False             False                 False
# 1              False             False                  True
# ...
